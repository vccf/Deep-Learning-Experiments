# %% [markdown]
# <a href="https://colab.research.google.com/github/vccf/Deep-Learning-Experiments/blob/main/Comet_and_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://cdn.comet.ml/img/notebook_logo.png">
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab) builds tools that help data scientists, engineers, and team leaders accelerate and optimize machine learning and deep learning models.
#
# Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab)!
#
# Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# If you'd like to learn more about Comet checkout our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab)

# %% [markdown]
# # Install Comet

# %%
# %pip install comet_ml --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 790.5/790.5 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 76.1 MB/s eta 0:00:00

# %% [markdown]
# # Initialize Comet

# %%
import comet_ml
comet_ml.init(project_name='comet-example-yolov5')
# Out:
# COMET WARNING: comet_ml.init() is deprecated and will be removed soon. Please use comet_ml.login()
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %% [markdown]
# # Setup YOLOv5

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17972, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 17972 (delta 75), reused 35 (delta 35), pack-reused 17876 (from 3)
# Receiving objects: 100% (17972/17972), 17.14 MiB | 27.50 MiB/s, done.
# Resolving deltas: 100% (12235/12235), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 11.7 MB/s eta 0:00:00

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.2/112.6 GB disk)

# %% [markdown]
# # Run the Training Script

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --bbox_interval 1 --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/6fb7f47e92254f0a991a32c6deae2613
#
#
# Dataset not found ⚠️, missing paths ['/content/datasets/coco128/images/train2017']
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/coco128.zip to coco128.zip...
# 100% 6.66M/6.66M [00:00<00:00, 103MB/s]
# Dataset download success ✅ (0.4s), saved to /content/datasets
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 180MB/s]
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /content/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<00:00, 1324.88it/s]
# train: New cache created: /content/datasets/coco128/labels/train2017.cache
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# /content/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.52G    0.04429    0.06439    0.01392        197        640:  12% 1/8 [00:03<00:24,  3.45s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G    0.04407    0.05901    0.01749        154        640:  25% 2/8 [00:03<00:09,  1.63s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G    0.04462     0.0584    0.01643        180        640:  38% 3/8 [00:04<00:05,  1.03s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G    0.04398    0.05708     0.0173        158        640:  50% 4/8 [00:04<00:03,  1.09it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G    0.04501     0.0593    0.01752        198        640:  62% 5/8 [00:05<00:02,  1.31it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G    0.04487    0.05856    0.01718        163        640:  75% 6/8 [00:05<00:01,  1.41it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G    0.04522    0.06052    0.01704        221        640:  88% 7/8 [00:06<00:00,  1.65it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.56G     0.0455    0.06219    0.01654        237        640: 100% 8/8 [00:06<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:11<00:00,  2.99s/it]
#                    all        128        929      0.688      0.603      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04029    0.08238    0.01446        250        640:  12% 1/8 [00:00<00:02,  2.77it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04202     0.0756    0.01438        231        640:  25% 2/8 [00:00<00:02,  2.71it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04275     0.0734    0.01641        209        640:  38% 3/8 [00:01<00:01,  2.70it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04341    0.07161    0.01734        230        640:  50% 4/8 [00:01<00:01,  2.69it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04255    0.07061    0.01646        217        640:  62% 5/8 [00:01<00:01,  2.56it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04275    0.06488    0.01756        103        640:  75% 6/8 [00:02<00:00,  2.78it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G    0.04343    0.06409    0.01707        200        640:  88% 7/8 [00:02<00:00,  2.89it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      5.18G     0.0436    0.06477    0.01679        245        640: 100% 8/8 [00:02<00:00,  2.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.12it/s]
#                    all        128        929      0.741      0.602      0.711      0.478
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04306    0.05803    0.01406        180        640:  12% 1/8 [00:00<00:01,  3.95it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04642    0.07693    0.01581        308        640:  25% 2/8 [00:00<00:01,  4.40it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04688      0.077    0.01653        293        640:  38% 3/8 [00:00<00:01,  3.75it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04631    0.07451    0.01537        190        640:  50% 4/8 [00:01<00:01,  3.86it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04615    0.07533    0.01551        272        640:  62% 5/8 [00:01<00:00,  3.53it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04613    0.07437    0.01525        232        640:  75% 6/8 [00:01<00:00,  3.65it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04567    0.07139     0.0157        169        640:  88% 7/8 [00:01<00:00,  3.60it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      5.18G    0.04549    0.07039    0.01537        217        640: 100% 8/8 [00:02<00:00,  3.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.96it/s]
#                    all        128        929      0.751      0.612      0.721      0.484
#
# 3 epochs completed in 0.009 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.8MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.11s/it]
#                    all        128        929      0.753      0.612      0.721      0.485
#                 person        128        254      0.882      0.704      0.798      0.526
#                bicycle        128          6      0.695      0.389      0.725      0.411
#                    car        128         46      0.728      0.348      0.516      0.219
#             motorcycle        128          5      0.492        0.8      0.665      0.529
#               airplane        128          6          1      0.958      0.995      0.697
#                    bus        128          7      0.549      0.714      0.747      0.655
#                  train        128          3      0.549      0.333       0.83      0.523
#                  truck        128         12       0.77      0.333      0.437      0.213
#                   boat        128          6      0.812      0.333      0.538      0.229
#          traffic light        128         14      0.573      0.195      0.364      0.212
#              stop sign        128          2      0.823          1      0.995      0.821
#                  bench        128          9      0.821      0.444      0.623      0.276
#                   bird        128         16      0.986          1      0.995      0.628
#                    cat        128          4      0.909          1      0.995      0.797
#                    dog        128          9          1      0.658      0.883      0.634
#                  horse        128          2      0.888          1      0.995      0.622
#               elephant        128         17      0.971      0.882      0.939      0.711
#                   bear        128          1      0.706          1      0.995      0.895
#                  zebra        128          4      0.863          1      0.995      0.923
#                giraffe        128          9      0.843      0.889      0.931      0.772
#               backpack        128          6          1      0.497      0.678      0.302
#               umbrella        128         18      0.878      0.778      0.869      0.504
#                handbag        128         19       0.78      0.263      0.334      0.176
#                    tie        128          7      0.826      0.681      0.763      0.487
#               suitcase        128          4      0.786          1      0.945      0.593
#                frisbee        128          5      0.729        0.8       0.76      0.729
#                   skis        128          1          0          0      0.111     0.0884
#              snowboard        128          7      0.805      0.591      0.847      0.536
#            sports ball        128          6      0.659      0.667      0.602      0.355
#                   kite        128         10      0.591        0.4      0.585      0.212
#           baseball bat        128          4       0.98        0.5      0.541      0.193
#         baseball glove        128          7       0.57      0.429      0.461      0.283
#             skateboard        128          5      0.603        0.4      0.631      0.426
#          tennis racket        128          7      0.797      0.429      0.538      0.291
#                 bottle        128         18      0.558      0.333      0.514      0.254
#             wine glass        128         16      0.747      0.875      0.898      0.482
#                    cup        128         36      0.833      0.556      0.767       0.51
#                   fork        128          6          1      0.312      0.462      0.303
#                  knife        128         16      0.807      0.688      0.733      0.418
#                  spoon        128         22      0.795      0.455      0.631      0.358
#                   bowl        128         28      0.894      0.604      0.743      0.563
#                 banana        128          1      0.927          1      0.995      0.206
#               sandwich        128          2          1          0       0.62      0.546
#                 orange        128          4      0.919          1      0.995      0.639
#               broccoli        128         11      0.442      0.455      0.429      0.332
#                 carrot        128         24      0.702      0.589      0.711      0.485
#                hot dog        128          2      0.535          1      0.995      0.895
#                  pizza        128          5       0.81        0.8      0.906      0.712
#                  donut        128         14      0.654          1      0.944      0.808
#                   cake        128          4      0.856          1      0.995       0.81
#                  chair        128         35      0.569      0.565      0.599       0.32
#                  couch        128          6      0.898      0.667       0.84      0.537
#           potted plant        128         14      0.723      0.786      0.825      0.509
#                    bed        128          3       0.48      0.333      0.597      0.313
#           dining table        128         13      0.809      0.327       0.54      0.334
#                 toilet        128          2      0.884          1      0.995      0.846
#                     tv        128          2      0.549          1      0.995      0.846
#                 laptop        128          3          1          0      0.755      0.305
#                  mouse        128          2          1          0     0.0348     0.0174
#                 remote        128          8          1      0.616      0.633       0.55
#             cell phone        128          8      0.508       0.26      0.412      0.221
#              microwave        128          3       0.77          1      0.995      0.755
#                   oven        128          5      0.398        0.4      0.456      0.305
#                   sink        128          6      0.477      0.311      0.346      0.253
#           refrigerator        128          5       0.58        0.8      0.803      0.568
#                   book        128         29      0.636      0.207      0.335      0.162
#                  clock        128          9      0.891      0.889       0.93      0.749
#                   vase        128          2      0.368          1      0.995      0.895
#               scissors        128          1          1          0      0.497     0.0498
#             teddy bear        128         21      0.767       0.47       0.73      0.505
#             toothbrush        128          5      0.779      0.716      0.928      0.607
# Results saved to runs/train/exp
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/6fb7f47e92254f0a991a32c6deae2613
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [3]                 : (1.9616692066192627, 2.243001699447632)
# COMET INFO:     metrics/mAP_0.5 [6]      : (0.6860396060267557, 0.7209873711758963)
# COMET INFO:     metrics/mAP_0.5:0.95 [6] : (0.45314582191797603, 0.48446208161269766)
# COMET INFO:     metrics/precision [6]    : (0.687996176511977, 0.7510794599154134)
# COMET INFO:     metrics/recall [6]       : (0.6021404956995021, 0.6121079005794993)
# COMET INFO:     train/box_loss [6]       : (0.04360292851924896, 0.045501384884119034)
# COMET INFO:     train/cls_loss [6]       : (0.015367417596280575, 0.016785548999905586)
# COMET INFO:     train/obj_loss [6]       : (0.062190942466259, 0.0703861340880394)
# COMET INFO:     val/box_loss [6]         : (0.04023745656013489, 0.041477397084236145)
# COMET INFO:     val/cls_loss [6]         : (0.008971691131591797, 0.010736465454101562)
# COMET INFO:     val/obj_loss [6]         : (0.037026405334472656, 0.038483619689941406)
# COMET INFO:     x/lr0 [6]                : (0.077782, 0.0937)
# COMET INFO:     x/lr1 [6]                : (0.0007, 0.001005)
# COMET INFO:     x/lr2 [6]                : (0.0007, 0.001005)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : victoria-celia-cesar-ferreira/comet-example-yolov5/6fb7f47e92254f0a991a32c6deae2613
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.93 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# # Configure Comet Logging

# %% [markdown]
# ## Logging Checkpoints with Comet
#
# Logging Models to Comet is disabled by default. To enable it, pass the `save-period` argument to the training script. This will save the
# logged checkpoints to Comet based on the interval value provided by `save-period`
#
# Checkpoints can be found in the [Assets and Artifacts](https://www.comet.com/examples/comet-example-yolov5/a0e29e0e9b984e4a822db2a62d0cb357?experiment-tab=assets?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab) tab in your Experiment

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1 \
--save-period 1
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/27fa1e16a6b14b3b9d2335a5edbfbed4
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp2/labels.jpg...
# /content/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.52G    0.04429    0.06439    0.01392        197        640:  12% 1/8 [00:03<00:22,  3.15s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04407    0.05901    0.01749        154        640:  25% 2/8 [00:03<00:08,  1.49s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04462     0.0584    0.01643        180        640:  38% 3/8 [00:03<00:04,  1.03it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04398    0.05708     0.0173        158        640:  50% 4/8 [00:04<00:03,  1.27it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04501     0.0593    0.01752        198        640:  62% 5/8 [00:04<00:01,  1.59it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04487    0.05856    0.01718        163        640:  75% 6/8 [00:04<00:01,  1.95it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04522    0.06052    0.01704        221        640:  88% 7/8 [00:05<00:00,  2.37it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G     0.0455    0.06219    0.01654        237        640: 100% 8/8 [00:05<00:00,  1.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:10<00:00,  2.72s/it]
#                    all        128        929      0.688      0.603      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04029    0.08238    0.01446        250        640:  12% 1/8 [00:00<00:01,  3.64it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04202    0.07559    0.01437        231        640:  25% 2/8 [00:00<00:01,  3.61it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04274    0.07337     0.0164        209        640:  38% 3/8 [00:00<00:01,  3.53it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G     0.0434    0.07157    0.01732        230        640:  50% 4/8 [00:01<00:01,  3.26it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04254    0.07056    0.01644        217        640:  62% 5/8 [00:01<00:00,  3.13it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04275    0.06484    0.01753        103        640:  75% 6/8 [00:01<00:00,  3.24it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04342    0.06405    0.01704        200        640:  88% 7/8 [00:02<00:00,  3.21it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04359    0.06471    0.01674        245        640: 100% 8/8 [00:02<00:00,  3.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.16s/it]
#                    all        128        929       0.74      0.606      0.712       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G      0.043    0.05793    0.01393        180        640:  12% 1/8 [00:00<00:02,  3.48it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04637    0.07675    0.01568        308        640:  25% 2/8 [00:00<00:01,  3.27it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04684    0.07683    0.01638        293        640:  38% 3/8 [00:00<00:01,  3.06it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04627    0.07429     0.0152        190        640:  50% 4/8 [00:01<00:01,  2.63it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04612    0.07508    0.01533        272        640:  62% 5/8 [00:01<00:01,  2.68it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04608    0.07408    0.01506        232        640:  75% 6/8 [00:02<00:00,  2.86it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04561     0.0711    0.01551        169        640:  88% 7/8 [00:02<00:00,  2.85it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04543    0.07007    0.01516        217        640: 100% 8/8 [00:02<00:00,  2.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.62it/s]
#                    all        128        929      0.749      0.619      0.725      0.485
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G     0.0437    0.05881    0.01532        209        640:  12% 1/8 [00:00<00:01,  3.63it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04584    0.06511    0.01573        273        640:  25% 2/8 [00:00<00:01,  3.83it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04513    0.06103    0.01626        164        640:  38% 3/8 [00:00<00:01,  3.49it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04538    0.06103    0.01609        214        640:  50% 4/8 [00:01<00:01,  2.84it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04555    0.06131    0.01607        229        640:  62% 5/8 [00:01<00:01,  2.17it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04588    0.06204    0.01587        260        640:  75% 6/8 [00:02<00:00,  2.14it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04578    0.06236    0.01544        214        640:  88% 7/8 [00:02<00:00,  2.11it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04498    0.06093    0.01524        194        640: 100% 8/8 [00:03<00:00,  2.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.29it/s]
#                    all        128        929      0.783      0.619      0.738      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04838    0.07358    0.01403        284        640:  12% 1/8 [00:00<00:01,  3.54it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04556    0.06641    0.01303        192        640:  25% 2/8 [00:00<00:01,  4.06it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04457     0.0648    0.01525        203        640:  38% 3/8 [00:00<00:01,  3.52it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04301    0.06488    0.01491        199        640:  50% 4/8 [00:01<00:01,  2.88it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04299     0.0633    0.01436        215        640:  62% 5/8 [00:01<00:01,  2.44it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04244    0.06063    0.01436        183        640:  75% 6/8 [00:02<00:00,  2.67it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04288    0.06288    0.01464        284        640:  88% 7/8 [00:02<00:00,  2.84it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04249    0.06219     0.0146        168        640: 100% 8/8 [00:02<00:00,  2.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.60it/s]
#                    all        128        929       0.77      0.668      0.762      0.509
#
# 5 epochs completed in 0.014 hours.
# Optimizer stripped from runs/train/exp2/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, 14.8MB
#
# Validating runs/train/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.04s/it]
#                    all        128        929      0.769      0.668      0.762       0.51
#                 person        128        254      0.862      0.716      0.807      0.536
#                bicycle        128          6      0.776      0.586      0.623      0.363
#                    car        128         46      0.663      0.478      0.561      0.239
#             motorcycle        128          5      0.779          1      0.962      0.741
#               airplane        128          6      0.992          1      0.995      0.745
#                    bus        128          7      0.621      0.714      0.721      0.635
#                  train        128          3          1      0.733      0.995      0.472
#                  truck        128         12      0.732      0.333      0.523      0.281
#                   boat        128          6          1       0.39      0.582      0.311
#          traffic light        128         14        0.7      0.335      0.374      0.248
#              stop sign        128          2      0.754          1      0.995      0.747
#                  bench        128          9      0.657      0.667      0.739      0.366
#                   bird        128         16      0.969          1      0.995      0.678
#                    cat        128          4      0.854          1      0.995      0.797
#                    dog        128          9      0.982      0.667      0.912      0.681
#                  horse        128          2      0.815          1      0.995      0.622
#               elephant        128         17          1      0.916      0.946      0.718
#                   bear        128          1      0.676          1      0.995      0.895
#                  zebra        128          4      0.863          1      0.995      0.886
#                giraffe        128          9      0.842      0.889      0.931      0.782
#               backpack        128          6      0.863        0.5      0.715      0.374
#               umbrella        128         18      0.799      0.885      0.881      0.508
#                handbag        128         19      0.611      0.263      0.351      0.191
#                    tie        128          7      0.718      0.714      0.787      0.478
#               suitcase        128          4      0.868          1      0.995      0.611
#                frisbee        128          5       0.72        0.8        0.8      0.727
#                   skis        128          1      0.825          1      0.995      0.317
#              snowboard        128          7          1      0.713       0.89      0.533
#            sports ball        128          6      0.669      0.667      0.621      0.311
#                   kite        128         10      0.606        0.6      0.599      0.253
#           baseball bat        128          4      0.841        0.5      0.544      0.233
#         baseball glove        128          7      0.553      0.429      0.464      0.283
#             skateboard        128          5      0.739        0.6       0.68      0.491
#          tennis racket        128          7      0.509      0.429      0.548      0.292
#                 bottle        128         18      0.571       0.37      0.532      0.254
#             wine glass        128         16      0.709      0.875        0.9      0.487
#                    cup        128         36      0.817      0.619      0.837       0.53
#                   fork        128          6          1      0.324      0.521      0.322
#                  knife        128         16       0.78       0.75       0.75      0.425
#                  spoon        128         22      0.743        0.5      0.644      0.384
#                   bowl        128         28      0.899      0.643      0.771      0.558
#                 banana        128          1      0.815          1      0.995      0.307
#               sandwich        128          2          1          0      0.662      0.579
#                 orange        128          4      0.786          1      0.995       0.66
#               broccoli        128         11      0.324      0.524      0.516      0.362
#                 carrot        128         24       0.69      0.743      0.746      0.495
#                hot dog        128          2      0.525          1      0.995      0.895
#                  pizza        128          5       0.87        0.8       0.92      0.729
#                  donut        128         14      0.604          1       0.95      0.824
#                   cake        128          4      0.854          1      0.995      0.772
#                  chair        128         35      0.546      0.629      0.637      0.356
#                  couch        128          6      0.881      0.667       0.86      0.547
#           potted plant        128         14      0.643      0.714      0.784      0.499
#                    bed        128          3          1          0      0.753      0.499
#           dining table        128         13      0.825      0.365      0.581      0.334
#                 toilet        128          2      0.782          1      0.995      0.895
#                     tv        128          2      0.715          1      0.995      0.796
#                 laptop        128          3          1          0       0.83      0.499
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.613      0.629      0.531
#             cell phone        128          8      0.655      0.375      0.491      0.296
#              microwave        128          3      0.794          1      0.995      0.744
#                   oven        128          5      0.385        0.4      0.474       0.32
#                   sink        128          6      0.444      0.333        0.4       0.31
#           refrigerator        128          5      0.572        0.8      0.811      0.547
#                   book        128         29      0.597      0.276      0.372      0.183
#                  clock        128          9      0.876      0.889      0.951      0.702
#                   vase        128          2      0.512          1      0.995      0.895
#               scissors        128          1          1          0      0.497     0.0995
#             teddy bear        128         21      0.719      0.732      0.796      0.519
#             toothbrush        128          5      0.796          1      0.995      0.706
# Results saved to runs/train/exp2
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/27fa1e16a6b14b3b9d2335a5edbfbed4
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.9564577341079712, 2.2340574264526367)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6860396060267557, 0.7615284201521582)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.45314582191797603, 0.5092766298013401)
# COMET INFO:     metrics/precision [10]    : (0.687996176511977, 0.7831448740091492)
# COMET INFO:     metrics/recall [10]       : (0.602999074233154, 0.667936975820754)
# COMET INFO:     train/box_loss [10]       : (0.04249417409300804, 0.045501384884119034)
# COMET INFO:     train/cls_loss [10]       : (0.014602642506361008, 0.016743825748562813)
# COMET INFO:     train/obj_loss [10]       : (0.06093379110097885, 0.07007072865962982)
# COMET INFO:     val/box_loss [10]         : (0.03937961161136627, 0.041477397084236145)
# COMET INFO:     val/cls_loss [10]         : (0.0077555179595947266, 0.010736465454101562)
# COMET INFO:     val/obj_loss [10]         : (0.035877227783203125, 0.038483619689941406)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : victoria-celia-cesar-ferreira/comet-example-yolov5/27fa1e16a6b14b3b9d2335a5edbfbed4
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp2
# COMET INFO:     save_period         : 1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.84 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     model-element       : 19 (1018.52 MB)
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 4 file(s), remaining 10.30 MB/15.56 MB

# %% [markdown]
# ## Logging Model Predictions
#
# You can log model predictions and the associated images by passing the `bbox_interval` command line argument. Predictions can be visualized using Comet's Object Detection Custom Panel
#
# **Note:** The YOLOv5 validation dataloader will default to a batch size of 32, so you will have to set the logging frequency accordingly.
#
# Here is an [example project using the Panel](https://www.comet.com/examples/comet-example-yolov5/view/1c4Dqcu8mZ767NBipjwlx3gz6/panels?shareable=YcwMiJaZSXfcEXpGOHDD12vA1&utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab)

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/c0818eede7cd4fc399080dcb6e5e7a70
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp3/labels.jpg...
# /content/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.52G    0.04429    0.06439    0.01392        197        640:  12% 1/8 [00:03<00:21,  3.10s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04407    0.05901    0.01749        154        640:  25% 2/8 [00:03<00:08,  1.48s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04462     0.0584    0.01643        180        640:  38% 3/8 [00:03<00:04,  1.05it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04398    0.05708     0.0173        158        640:  50% 4/8 [00:04<00:03,  1.28it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04501     0.0593    0.01752        198        640:  62% 5/8 [00:04<00:01,  1.58it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04487    0.05856    0.01718        163        640:  75% 6/8 [00:04<00:01,  1.99it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04522    0.06052    0.01704        221        640:  88% 7/8 [00:05<00:00,  2.25it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G     0.0455    0.06219    0.01654        237        640: 100% 8/8 [00:05<00:00,  1.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:10<00:00,  2.74s/it]
#                    all        128        929      0.688      0.603      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04029    0.08238    0.01446        250        640:  12% 1/8 [00:00<00:01,  3.53it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04202    0.07559    0.01437        231        640:  25% 2/8 [00:00<00:01,  3.72it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04274    0.07337     0.0164        209        640:  38% 3/8 [00:00<00:01,  3.42it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G     0.0434    0.07157    0.01732        230        640:  50% 4/8 [00:01<00:01,  3.55it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04254    0.07056    0.01644        217        640:  62% 5/8 [00:01<00:00,  3.43it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04275    0.06484    0.01753        103        640:  75% 6/8 [00:01<00:00,  3.52it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04342    0.06405    0.01704        200        640:  88% 7/8 [00:02<00:00,  3.39it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04359    0.06471    0.01674        245        640: 100% 8/8 [00:02<00:00,  3.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.03s/it]
#                    all        128        929       0.74      0.606      0.712       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G      0.043    0.05793    0.01393        180        640:  12% 1/8 [00:00<00:01,  4.13it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04637    0.07675    0.01568        308        640:  25% 2/8 [00:00<00:01,  4.00it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04684    0.07683    0.01638        293        640:  38% 3/8 [00:00<00:01,  3.51it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04627    0.07429     0.0152        190        640:  50% 4/8 [00:01<00:01,  3.67it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04612    0.07508    0.01533        272        640:  62% 5/8 [00:01<00:00,  3.51it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04608    0.07408    0.01506        232        640:  75% 6/8 [00:01<00:00,  3.59it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04561     0.0711    0.01551        169        640:  88% 7/8 [00:01<00:00,  3.55it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04543    0.07007    0.01516        217        640: 100% 8/8 [00:02<00:00,  3.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.10it/s]
#                    all        128        929      0.749      0.619      0.725      0.485
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G     0.0437    0.05881    0.01532        209        640:  12% 1/8 [00:00<00:01,  4.01it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04584    0.06511    0.01573        273        640:  25% 2/8 [00:00<00:01,  3.86it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04513    0.06103    0.01626        164        640:  38% 3/8 [00:00<00:01,  3.65it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04538    0.06103    0.01609        214        640:  50% 4/8 [00:01<00:01,  3.68it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04555    0.06131    0.01607        229        640:  62% 5/8 [00:01<00:00,  3.52it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04588    0.06204    0.01587        260        640:  75% 6/8 [00:01<00:00,  3.56it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04578    0.06236    0.01544        214        640:  88% 7/8 [00:01<00:00,  3.34it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04498    0.06093    0.01524        194        640: 100% 8/8 [00:02<00:00,  3.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.85it/s]
#                    all        128        929      0.783      0.619      0.738      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04838    0.07358    0.01403        284        640:  12% 1/8 [00:00<00:02,  3.16it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04556    0.06641    0.01303        192        640:  25% 2/8 [00:00<00:01,  3.27it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04457     0.0648    0.01525        203        640:  38% 3/8 [00:01<00:01,  2.91it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04301    0.06488    0.01491        199        640:  50% 4/8 [00:01<00:01,  3.14it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04299     0.0633    0.01436        215        640:  62% 5/8 [00:01<00:01,  2.84it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04244    0.06063    0.01436        183        640:  75% 6/8 [00:01<00:00,  3.07it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04288    0.06288    0.01464        284        640:  88% 7/8 [00:02<00:00,  3.03it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04249    0.06219     0.0146        168        640: 100% 8/8 [00:02<00:00,  3.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.92it/s]
#                    all        128        929       0.77      0.668      0.762      0.509
#
# 5 epochs completed in 0.011 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.8MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.07it/s]
#                    all        128        929      0.769      0.668      0.762       0.51
#                 person        128        254      0.862      0.716      0.807      0.536
#                bicycle        128          6      0.776      0.586      0.623      0.363
#                    car        128         46      0.663      0.478      0.561      0.239
#             motorcycle        128          5      0.779          1      0.962      0.741
#               airplane        128          6      0.992          1      0.995      0.745
#                    bus        128          7      0.621      0.714      0.721      0.635
#                  train        128          3          1      0.733      0.995      0.472
#                  truck        128         12      0.732      0.333      0.523      0.281
#                   boat        128          6          1       0.39      0.582      0.311
#          traffic light        128         14        0.7      0.335      0.374      0.248
#              stop sign        128          2      0.754          1      0.995      0.747
#                  bench        128          9      0.657      0.667      0.739      0.366
#                   bird        128         16      0.969          1      0.995      0.678
#                    cat        128          4      0.854          1      0.995      0.797
#                    dog        128          9      0.982      0.667      0.912      0.681
#                  horse        128          2      0.815          1      0.995      0.622
#               elephant        128         17          1      0.916      0.946      0.718
#                   bear        128          1      0.676          1      0.995      0.895
#                  zebra        128          4      0.863          1      0.995      0.886
#                giraffe        128          9      0.842      0.889      0.931      0.782
#               backpack        128          6      0.863        0.5      0.715      0.374
#               umbrella        128         18      0.799      0.885      0.881      0.508
#                handbag        128         19      0.611      0.263      0.351      0.191
#                    tie        128          7      0.718      0.714      0.787      0.478
#               suitcase        128          4      0.868          1      0.995      0.611
#                frisbee        128          5       0.72        0.8        0.8      0.727
#                   skis        128          1      0.825          1      0.995      0.317
#              snowboard        128          7          1      0.713       0.89      0.533
#            sports ball        128          6      0.669      0.667      0.621      0.311
#                   kite        128         10      0.606        0.6      0.599      0.253
#           baseball bat        128          4      0.841        0.5      0.544      0.233
#         baseball glove        128          7      0.553      0.429      0.464      0.283
#             skateboard        128          5      0.739        0.6       0.68      0.491
#          tennis racket        128          7      0.509      0.429      0.548      0.292
#                 bottle        128         18      0.571       0.37      0.532      0.254
#             wine glass        128         16      0.709      0.875        0.9      0.487
#                    cup        128         36      0.817      0.619      0.837       0.53
#                   fork        128          6          1      0.324      0.521      0.322
#                  knife        128         16       0.78       0.75       0.75      0.425
#                  spoon        128         22      0.743        0.5      0.644      0.384
#                   bowl        128         28      0.899      0.643      0.771      0.558
#                 banana        128          1      0.815          1      0.995      0.307
#               sandwich        128          2          1          0      0.662      0.579
#                 orange        128          4      0.786          1      0.995       0.66
#               broccoli        128         11      0.324      0.524      0.516      0.362
#                 carrot        128         24       0.69      0.743      0.746      0.495
#                hot dog        128          2      0.525          1      0.995      0.895
#                  pizza        128          5       0.87        0.8       0.92      0.729
#                  donut        128         14      0.604          1       0.95      0.824
#                   cake        128          4      0.854          1      0.995      0.772
#                  chair        128         35      0.546      0.629      0.637      0.356
#                  couch        128          6      0.881      0.667       0.86      0.547
#           potted plant        128         14      0.643      0.714      0.784      0.499
#                    bed        128          3          1          0      0.753      0.499
#           dining table        128         13      0.825      0.365      0.581      0.334
#                 toilet        128          2      0.782          1      0.995      0.895
#                     tv        128          2      0.715          1      0.995      0.796
#                 laptop        128          3          1          0       0.83      0.499
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.613      0.629      0.531
#             cell phone        128          8      0.655      0.375      0.491      0.296
#              microwave        128          3      0.794          1      0.995      0.744
#                   oven        128          5      0.385        0.4      0.474       0.32
#                   sink        128          6      0.444      0.333        0.4       0.31
#           refrigerator        128          5      0.572        0.8      0.811      0.547
#                   book        128         29      0.597      0.276      0.372      0.183
#                  clock        128          9      0.876      0.889      0.951      0.702
#                   vase        128          2      0.512          1      0.995      0.895
#               scissors        128          1          1          0      0.497     0.0995
#             teddy bear        128         21      0.719      0.732      0.796      0.519
#             toothbrush        128          5      0.796          1      0.995      0.706
# Results saved to runs/train/exp3
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/c0818eede7cd4fc399080dcb6e5e7a70
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.9564577341079712, 2.2340574264526367)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6860396060267557, 0.7615284201521582)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.45314582191797603, 0.5092766298013401)
# COMET INFO:     metrics/precision [10]    : (0.687996176511977, 0.7831448740091492)
# COMET INFO:     metrics/recall [10]       : (0.602999074233154, 0.667936975820754)
# COMET INFO:     train/box_loss [10]       : (0.04249417409300804, 0.045501384884119034)
# COMET INFO:     train/cls_loss [10]       : (0.014602642506361008, 0.016743825748562813)
# COMET INFO:     train/obj_loss [10]       : (0.06093379110097885, 0.07007072865962982)
# COMET INFO:     val/box_loss [10]         : (0.03937961161136627, 0.041477397084236145)
# COMET INFO:     val/cls_loss [10]         : (0.0077555179595947266, 0.010736465454101562)
# COMET INFO:     val/obj_loss [10]         : (0.035877227783203125, 0.038483619689941406)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : victoria-celia-cesar-ferreira/comet-example-yolov5/c0818eede7cd4fc399080dcb6e5e7a70
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp3
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.84 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# ### Controlling the number of Prediction Images logged to Comet
#
# When logging predictions from YOLOv5, Comet will log the images associated with each set of predictions. By default a maximum of 100 validation images are logged. You can increase or decrease this number using the `COMET_MAX_IMAGE_UPLOADS` environment variable.

# %%
# !env COMET_MAX_IMAGE_UPLOADS=200 python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/de1ea5c0581e4c99ae375fe559d219fa
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# /content/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.52G    0.04429    0.06439    0.01392        197        640:  12% 1/8 [00:03<00:22,  3.15s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04407    0.05901    0.01749        154        640:  25% 2/8 [00:03<00:09,  1.50s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04462     0.0584    0.01643        180        640:  38% 3/8 [00:03<00:04,  1.02it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04398    0.05708     0.0173        158        640:  50% 4/8 [00:04<00:03,  1.28it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04501     0.0593    0.01752        198        640:  62% 5/8 [00:04<00:01,  1.57it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04487    0.05856    0.01718        163        640:  75% 6/8 [00:05<00:01,  1.92it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04522    0.06052    0.01704        221        640:  88% 7/8 [00:05<00:00,  2.23it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G     0.0455    0.06219    0.01654        237        640: 100% 8/8 [00:05<00:00,  1.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:11<00:00,  2.76s/it]
#                    all        128        929      0.688      0.603      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04029    0.08238    0.01446        250        640:  12% 1/8 [00:00<00:02,  3.35it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04202    0.07559    0.01437        231        640:  25% 2/8 [00:00<00:01,  3.64it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04274    0.07337     0.0164        209        640:  38% 3/8 [00:00<00:01,  3.49it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G     0.0434    0.07157    0.01732        230        640:  50% 4/8 [00:01<00:01,  3.39it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04254    0.07056    0.01644        217        640:  62% 5/8 [00:01<00:00,  3.34it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04275    0.06484    0.01753        103        640:  75% 6/8 [00:01<00:00,  3.10it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04342    0.06405    0.01704        200        640:  88% 7/8 [00:02<00:00,  2.99it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04359    0.06471    0.01674        245        640: 100% 8/8 [00:02<00:00,  3.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:10<00:00,  2.71s/it]
#                    all        128        929       0.74      0.606      0.712       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G      0.043    0.05793    0.01393        180        640:  12% 1/8 [00:00<00:02,  3.45it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04637    0.07675    0.01568        308        640:  25% 2/8 [00:00<00:01,  3.93it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04684    0.07683    0.01638        293        640:  38% 3/8 [00:00<00:01,  2.82it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04627    0.07429     0.0152        190        640:  50% 4/8 [00:01<00:01,  2.97it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04612    0.07508    0.01533        272        640:  62% 5/8 [00:01<00:01,  2.72it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04608    0.07408    0.01506        232        640:  75% 6/8 [00:02<00:00,  2.94it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04561     0.0711    0.01551        169        640:  88% 7/8 [00:02<00:00,  2.70it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04543    0.07007    0.01516        217        640: 100% 8/8 [00:02<00:00,  2.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.35s/it]
#                    all        128        929      0.749      0.619      0.725      0.485
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G     0.0437    0.05881    0.01532        209        640:  12% 1/8 [00:00<00:01,  3.85it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04584    0.06511    0.01573        273        640:  25% 2/8 [00:00<00:01,  3.74it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04513    0.06103    0.01626        164        640:  38% 3/8 [00:00<00:01,  3.34it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04538    0.06103    0.01609        214        640:  50% 4/8 [00:01<00:01,  3.61it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04555    0.06131    0.01607        229        640:  62% 5/8 [00:01<00:00,  3.45it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04588    0.06204    0.01587        260        640:  75% 6/8 [00:01<00:00,  3.40it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04578    0.06236    0.01544        214        640:  88% 7/8 [00:02<00:00,  3.33it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04498    0.06093    0.01524        194        640: 100% 8/8 [00:02<00:00,  3.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.08it/s]
#                    all        128        929      0.783      0.619      0.738      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04838    0.07358    0.01403        284        640:  12% 1/8 [00:00<00:01,  3.87it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04556    0.06641    0.01303        192        640:  25% 2/8 [00:00<00:01,  4.14it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04457     0.0648    0.01525        203        640:  38% 3/8 [00:00<00:01,  3.38it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04301    0.06488    0.01491        199        640:  50% 4/8 [00:01<00:01,  3.20it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04299     0.0633    0.01436        215        640:  62% 5/8 [00:01<00:01,  2.89it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04244    0.06063    0.01436        183        640:  75% 6/8 [00:01<00:00,  3.05it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04288    0.06288    0.01464        284        640:  88% 7/8 [00:02<00:00,  2.77it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04249    0.06219     0.0146        168        640: 100% 8/8 [00:02<00:00,  3.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.50it/s]
#                    all        128        929       0.77      0.668      0.762      0.509
#
# 5 epochs completed in 0.014 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.8MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.07it/s]
#                    all        128        929      0.769      0.668      0.762       0.51
#                 person        128        254      0.862      0.716      0.807      0.536
#                bicycle        128          6      0.776      0.586      0.623      0.363
#                    car        128         46      0.663      0.478      0.561      0.239
#             motorcycle        128          5      0.779          1      0.962      0.741
#               airplane        128          6      0.992          1      0.995      0.745
#                    bus        128          7      0.621      0.714      0.721      0.635
#                  train        128          3          1      0.733      0.995      0.472
#                  truck        128         12      0.732      0.333      0.523      0.281
#                   boat        128          6          1       0.39      0.582      0.311
#          traffic light        128         14        0.7      0.335      0.374      0.248
#              stop sign        128          2      0.754          1      0.995      0.747
#                  bench        128          9      0.657      0.667      0.739      0.366
#                   bird        128         16      0.969          1      0.995      0.678
#                    cat        128          4      0.854          1      0.995      0.797
#                    dog        128          9      0.982      0.667      0.912      0.681
#                  horse        128          2      0.815          1      0.995      0.622
#               elephant        128         17          1      0.916      0.946      0.718
#                   bear        128          1      0.676          1      0.995      0.895
#                  zebra        128          4      0.863          1      0.995      0.886
#                giraffe        128          9      0.842      0.889      0.931      0.782
#               backpack        128          6      0.863        0.5      0.715      0.374
#               umbrella        128         18      0.799      0.885      0.881      0.508
#                handbag        128         19      0.611      0.263      0.351      0.191
#                    tie        128          7      0.718      0.714      0.787      0.478
#               suitcase        128          4      0.868          1      0.995      0.611
#                frisbee        128          5       0.72        0.8        0.8      0.727
#                   skis        128          1      0.825          1      0.995      0.317
#              snowboard        128          7          1      0.713       0.89      0.533
#            sports ball        128          6      0.669      0.667      0.621      0.311
#                   kite        128         10      0.606        0.6      0.599      0.253
#           baseball bat        128          4      0.841        0.5      0.544      0.233
#         baseball glove        128          7      0.553      0.429      0.464      0.283
#             skateboard        128          5      0.739        0.6       0.68      0.491
#          tennis racket        128          7      0.509      0.429      0.548      0.292
#                 bottle        128         18      0.571       0.37      0.532      0.254
#             wine glass        128         16      0.709      0.875        0.9      0.487
#                    cup        128         36      0.817      0.619      0.837       0.53
#                   fork        128          6          1      0.324      0.521      0.322
#                  knife        128         16       0.78       0.75       0.75      0.425
#                  spoon        128         22      0.743        0.5      0.644      0.384
#                   bowl        128         28      0.899      0.643      0.771      0.558
#                 banana        128          1      0.815          1      0.995      0.307
#               sandwich        128          2          1          0      0.662      0.579
#                 orange        128          4      0.786          1      0.995       0.66
#               broccoli        128         11      0.324      0.524      0.516      0.362
#                 carrot        128         24       0.69      0.743      0.746      0.495
#                hot dog        128          2      0.525          1      0.995      0.895
#                  pizza        128          5       0.87        0.8       0.92      0.729
#                  donut        128         14      0.604          1       0.95      0.824
#                   cake        128          4      0.854          1      0.995      0.772
#                  chair        128         35      0.546      0.629      0.637      0.356
#                  couch        128          6      0.881      0.667       0.86      0.547
#           potted plant        128         14      0.643      0.714      0.784      0.499
#                    bed        128          3          1          0      0.753      0.499
#           dining table        128         13      0.825      0.365      0.581      0.334
#                 toilet        128          2      0.782          1      0.995      0.895
#                     tv        128          2      0.715          1      0.995      0.796
#                 laptop        128          3          1          0       0.83      0.499
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.613      0.629      0.531
#             cell phone        128          8      0.655      0.375      0.491      0.296
#              microwave        128          3      0.794          1      0.995      0.744
#                   oven        128          5      0.385        0.4      0.474       0.32
#                   sink        128          6      0.444      0.333        0.4       0.31
#           refrigerator        128          5      0.572        0.8      0.811      0.547
#                   book        128         29      0.597      0.276      0.372      0.183
#                  clock        128          9      0.876      0.889      0.951      0.702
#                   vase        128          2      0.512          1      0.995      0.895
#               scissors        128          1          1          0      0.497     0.0995
#             teddy bear        128         21      0.719      0.732      0.796      0.519
#             toothbrush        128          5      0.796          1      0.995      0.706
# Results saved to runs/train/exp4
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/de1ea5c0581e4c99ae375fe559d219fa
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.9564577341079712, 2.2340574264526367)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6860396060267557, 0.7615284201521582)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.45314582191797603, 0.5092766298013401)
# COMET INFO:     metrics/precision [10]    : (0.687996176511977, 0.7831448740091492)
# COMET INFO:     metrics/recall [10]       : (0.602999074233154, 0.667936975820754)
# COMET INFO:     train/box_loss [10]       : (0.04249417409300804, 0.045501384884119034)
# COMET INFO:     train/cls_loss [10]       : (0.014602642506361008, 0.016743825748562813)
# COMET INFO:     train/obj_loss [10]       : (0.06093379110097885, 0.07007072865962982)
# COMET INFO:     val/box_loss [10]         : (0.03937961161136627, 0.041477397084236145)
# COMET INFO:     val/cls_loss [10]         : (0.0077555179595947266, 0.010736465454101562)
# COMET INFO:     val/obj_loss [10]         : (0.035877227783203125, 0.038483619689941406)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : victoria-celia-cesar-ferreira/comet-example-yolov5/de1ea5c0581e4c99ae375fe559d219fa
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 200
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp4
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.77 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 206
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: All assets have been sent, waiting for delivery confirmation

# %% [markdown]
# ### Logging Class Level Metrics
#
# Use the `COMET_LOG_PER_CLASS_METRICS` environment variable to log mAP, precision, recall, f1 for each class.

# %%
# !env COMET_LOG_PER_CLASS_METRICS=true python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--bbox_interval 1 \
--weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/265245b0bb16487a96854e38fa69e9d6
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp5/labels.jpg...
# /content/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp5
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.52G    0.04429    0.06439    0.01392        197        640:  12% 1/8 [00:04<00:28,  4.07s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04407    0.05901    0.01749        154        640:  25% 2/8 [00:04<00:11,  1.87s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04462     0.0584    0.01643        180        640:  38% 3/8 [00:04<00:05,  1.18s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04398    0.05708     0.0173        158        640:  50% 4/8 [00:05<00:03,  1.03it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04501     0.0593    0.01752        198        640:  62% 5/8 [00:05<00:02,  1.42it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04487    0.05856    0.01718        163        640:  75% 6/8 [00:05<00:01,  1.78it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04522    0.06052    0.01704        221        640:  88% 7/8 [00:06<00:00,  2.12it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G     0.0455    0.06219    0.01654        237        640: 100% 8/8 [00:06<00:00,  1.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:10<00:00,  2.67s/it]
#                    all        128        929      0.688      0.603      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04029    0.08238    0.01446        250        640:  12% 1/8 [00:00<00:02,  3.45it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04202    0.07559    0.01437        231        640:  25% 2/8 [00:00<00:01,  3.60it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04274    0.07337     0.0164        209        640:  38% 3/8 [00:00<00:01,  3.41it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G     0.0434    0.07157    0.01732        230        640:  50% 4/8 [00:01<00:01,  3.65it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04254    0.07056    0.01644        217        640:  62% 5/8 [00:01<00:00,  3.41it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04275    0.06484    0.01753        103        640:  75% 6/8 [00:01<00:00,  3.41it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04342    0.06405    0.01704        200        640:  88% 7/8 [00:02<00:00,  3.38it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04359    0.06471    0.01674        245        640: 100% 8/8 [00:02<00:00,  3.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.18it/s]
#                    all        128        929       0.74      0.606      0.712       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G      0.043    0.05793    0.01393        180        640:  12% 1/8 [00:00<00:01,  3.76it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04637    0.07675    0.01568        308        640:  25% 2/8 [00:00<00:01,  3.84it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04684    0.07683    0.01638        293        640:  38% 3/8 [00:00<00:01,  3.40it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04627    0.07429     0.0152        190        640:  50% 4/8 [00:01<00:01,  3.60it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04612    0.07508    0.01533        272        640:  62% 5/8 [00:01<00:00,  3.20it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04608    0.07408    0.01506        232        640:  75% 6/8 [00:01<00:00,  3.14it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04561     0.0711    0.01551        169        640:  88% 7/8 [00:02<00:00,  2.89it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04543    0.07007    0.01516        217        640: 100% 8/8 [00:02<00:00,  3.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.49it/s]
#                    all        128        929      0.749      0.619      0.725      0.485
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G     0.0437    0.05881    0.01532        209        640:  12% 1/8 [00:00<00:01,  3.83it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04584    0.06511    0.01573        273        640:  25% 2/8 [00:00<00:01,  3.80it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04513    0.06103    0.01626        164        640:  38% 3/8 [00:00<00:01,  3.79it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04538    0.06103    0.01609        214        640:  50% 4/8 [00:01<00:01,  3.95it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04555    0.06131    0.01607        229        640:  62% 5/8 [00:01<00:00,  3.56it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04588    0.06204    0.01587        260        640:  75% 6/8 [00:01<00:00,  3.59it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04578    0.06236    0.01544        214        640:  88% 7/8 [00:01<00:00,  3.46it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04498    0.06093    0.01524        194        640: 100% 8/8 [00:02<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.97it/s]
#                    all        128        929      0.783      0.619      0.738      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04838    0.07358    0.01403        284        640:  12% 1/8 [00:00<00:01,  3.84it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04556    0.06641    0.01303        192        640:  25% 2/8 [00:00<00:01,  3.87it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04457     0.0648    0.01525        203        640:  38% 3/8 [00:00<00:01,  3.68it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04301    0.06488    0.01491        199        640:  50% 4/8 [00:01<00:01,  3.76it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04299     0.0633    0.01436        215        640:  62% 5/8 [00:01<00:00,  3.56it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04244    0.06063    0.01436        183        640:  75% 6/8 [00:01<00:00,  3.61it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04288    0.06288    0.01464        284        640:  88% 7/8 [00:01<00:00,  3.45it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04249    0.06219     0.0146        168        640: 100% 8/8 [00:02<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.96it/s]
#                    all        128        929       0.77      0.668      0.762      0.509
#
# 5 epochs completed in 0.011 hours.
# Optimizer stripped from runs/train/exp5/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp5/weights/best.pt, 14.8MB
#
# Validating runs/train/exp5/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        128        929      0.769      0.668      0.762       0.51
#                 person        128        254      0.862      0.716      0.807      0.536
#                bicycle        128          6      0.776      0.586      0.623      0.363
#                    car        128         46      0.663      0.478      0.561      0.239
#             motorcycle        128          5      0.779          1      0.962      0.741
#               airplane        128          6      0.992          1      0.995      0.745
#                    bus        128          7      0.621      0.714      0.721      0.635
#                  train        128          3          1      0.733      0.995      0.472
#                  truck        128         12      0.732      0.333      0.523      0.281
#                   boat        128          6          1       0.39      0.582      0.311
#          traffic light        128         14        0.7      0.335      0.374      0.248
#              stop sign        128          2      0.754          1      0.995      0.747
#                  bench        128          9      0.657      0.667      0.739      0.366
#                   bird        128         16      0.969          1      0.995      0.678
#                    cat        128          4      0.854          1      0.995      0.797
#                    dog        128          9      0.982      0.667      0.912      0.681
#                  horse        128          2      0.815          1      0.995      0.622
#               elephant        128         17          1      0.916      0.946      0.718
#                   bear        128          1      0.676          1      0.995      0.895
#                  zebra        128          4      0.863          1      0.995      0.886
#                giraffe        128          9      0.842      0.889      0.931      0.782
#               backpack        128          6      0.863        0.5      0.715      0.374
#               umbrella        128         18      0.799      0.885      0.881      0.508
#                handbag        128         19      0.611      0.263      0.351      0.191
#                    tie        128          7      0.718      0.714      0.787      0.478
#               suitcase        128          4      0.868          1      0.995      0.611
#                frisbee        128          5       0.72        0.8        0.8      0.727
#                   skis        128          1      0.825          1      0.995      0.317
#              snowboard        128          7          1      0.713       0.89      0.533
#            sports ball        128          6      0.669      0.667      0.621      0.311
#                   kite        128         10      0.606        0.6      0.599      0.253
#           baseball bat        128          4      0.841        0.5      0.544      0.233
#         baseball glove        128          7      0.553      0.429      0.464      0.283
#             skateboard        128          5      0.739        0.6       0.68      0.491
#          tennis racket        128          7      0.509      0.429      0.548      0.292
#                 bottle        128         18      0.571       0.37      0.532      0.254
#             wine glass        128         16      0.709      0.875        0.9      0.487
#                    cup        128         36      0.817      0.619      0.837       0.53
#                   fork        128          6          1      0.324      0.521      0.322
#                  knife        128         16       0.78       0.75       0.75      0.425
#                  spoon        128         22      0.743        0.5      0.644      0.384
#                   bowl        128         28      0.899      0.643      0.771      0.558
#                 banana        128          1      0.815          1      0.995      0.307
#               sandwich        128          2          1          0      0.662      0.579
#                 orange        128          4      0.786          1      0.995       0.66
#               broccoli        128         11      0.324      0.524      0.516      0.362
#                 carrot        128         24       0.69      0.743      0.746      0.495
#                hot dog        128          2      0.525          1      0.995      0.895
#                  pizza        128          5       0.87        0.8       0.92      0.729
#                  donut        128         14      0.604          1       0.95      0.824
#                   cake        128          4      0.854          1      0.995      0.772
#                  chair        128         35      0.546      0.629      0.637      0.356
#                  couch        128          6      0.881      0.667       0.86      0.547
#           potted plant        128         14      0.643      0.714      0.784      0.499
#                    bed        128          3          1          0      0.753      0.499
#           dining table        128         13      0.825      0.365      0.581      0.334
#                 toilet        128          2      0.782          1      0.995      0.895
#                     tv        128          2      0.715          1      0.995      0.796
#                 laptop        128          3          1          0       0.83      0.499
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.613      0.629      0.531
#             cell phone        128          8      0.655      0.375      0.491      0.296
#              microwave        128          3      0.794          1      0.995      0.744
#                   oven        128          5      0.385        0.4      0.474       0.32
#                   sink        128          6      0.444      0.333        0.4       0.31
#           refrigerator        128          5      0.572        0.8      0.811      0.547
#                   book        128         29      0.597      0.276      0.372      0.183
#                  clock        128          9      0.876      0.889      0.951      0.702
#                   vase        128          2      0.512          1      0.995      0.895
#               scissors        128          1          1          0      0.497     0.0995
#             teddy bear        128         21      0.719      0.732      0.796      0.519
#             toothbrush        128          5      0.796          1      0.995      0.706
# Results saved to runs/train/exp5
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/265245b0bb16487a96854e38fa69e9d6
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     airplane_f1                    : 0.9961172475028347
# COMET INFO:     airplane_false_positives       : 0.0
# COMET INFO:     airplane_mAP@.5                : 0.995
# COMET INFO:     airplane_mAP@.5:.95            : 0.7449497069885418
# COMET INFO:     airplane_precision             : 0.9922645299214337
# COMET INFO:     airplane_recall                : 1.0
# COMET INFO:     airplane_support               : 6
# COMET INFO:     airplane_true_positives        : 6.0
# COMET INFO:     backpack_f1                    : 0.6332847308096935
# COMET INFO:     backpack_false_positives       : 0.0
# COMET INFO:     backpack_mAP@.5                : 0.7154800366300366
# COMET INFO:     backpack_mAP@.5:.95            : 0.3738561548451548
# COMET INFO:     backpack_precision             : 0.8634556344053551
# COMET INFO:     backpack_recall                : 0.5
# COMET INFO:     backpack_support               : 6
# COMET INFO:     backpack_true_positives        : 3.0
# COMET INFO:     banana_f1                      : 0.8977803738317758
# COMET INFO:     banana_false_positives         : 0.0
# COMET INFO:     banana_mAP@.5                  : 0.995
# COMET INFO:     banana_mAP@.5:.95              : 0.3071521739130435
# COMET INFO:     banana_precision               : 0.8145204027556969
# COMET INFO:     banana_recall                  : 1.0
# COMET INFO:     banana_support                 : 1
# COMET INFO:     banana_true_positives          : 1.0
# COMET INFO:     baseball bat_f1                : 0.6272436862570535
# COMET INFO:     baseball bat_false_positives   : 0.0
# COMET INFO:     baseball bat_mAP@.5            : 0.5439605614973263
# COMET INFO:     baseball bat_mAP@.5:.95        : 0.2329795454545455
# COMET INFO:     baseball bat_precision         : 0.8413589027624115
# COMET INFO:     baseball bat_recall            : 0.5
# COMET INFO:     baseball bat_support           : 4
# COMET INFO:     baseball bat_true_positives    : 2.0
# COMET INFO:     baseball glove_f1              : 0.4829041495511534
# COMET INFO:     baseball glove_false_positives : 2.0
# COMET INFO:     baseball glove_mAP@.5          : 0.4637465119637422
# COMET INFO:     baseball glove_mAP@.5:.95      : 0.28293766632971196
# COMET INFO:     baseball glove_precision       : 0.5530131358352217
# COMET INFO:     baseball glove_recall          : 0.42857142857142855
# COMET INFO:     baseball glove_support         : 7
# COMET INFO:     baseball glove_true_positives  : 3.0
# COMET INFO:     bear_f1                        : 0.8065571609110759
# COMET INFO:     bear_false_positives           : 0.0
# COMET INFO:     bear_mAP@.5                    : 0.995
# COMET INFO:     bear_mAP@.5:.95                : 0.8955
# COMET INFO:     bear_precision                 : 0.6758238723245453
# COMET INFO:     bear_recall                    : 1.0
# COMET INFO:     bear_support                   : 1
# COMET INFO:     bear_true_positives            : 1.0
# COMET INFO:     bed_f1                         : 0.0
# COMET INFO:     bed_false_positives            : 0.0
# COMET INFO:     bed_mAP@.5                     : 0.753
# COMET INFO:     bed_mAP@.5:.95                 : 0.49872291390728474
# COMET INFO:     bed_precision                  : 1.0
# COMET INFO:     bed_recall                     : 0.0
# COMET INFO:     bed_support                    : 3
# COMET INFO:     bed_true_positives             : 0.0
# COMET INFO:     bench_f1                       : 0.6615737041180545
# COMET INFO:     bench_false_positives          : 3.0
# COMET INFO:     bench_mAP@.5                   : 0.7390666666666666
# COMET INFO:     bench_mAP@.5:.95               : 0.3664210665553638
# COMET INFO:     bench_precision                : 0.6565579664171213
# COMET INFO:     bench_recall                   : 0.6666666666666666
# COMET INFO:     bench_support                  : 9
# COMET INFO:     bench_true_positives           : 6.0
# COMET INFO:     bicycle_f1                     : 0.6673612266088036
# COMET INFO:     bicycle_false_positives        : 1.0
# COMET INFO:     bicycle_mAP@.5                 : 0.6230833333333333
# COMET INFO:     bicycle_mAP@.5:.95             : 0.36289324305555554
# COMET INFO:     bicycle_precision              : 0.7756768336459854
# COMET INFO:     bicycle_recall                 : 0.5855894454866177
# COMET INFO:     bicycle_support                : 6
# COMET INFO:     bicycle_true_positives         : 4.0
# COMET INFO:     bird_f1                        : 0.9841670326589288
# COMET INFO:     bird_false_positives           : 1.0
# COMET INFO:     bird_mAP@.5                    : 0.995
# COMET INFO:     bird_mAP@.5:.95                : 0.6780196478424156
# COMET INFO:     bird_precision                 : 0.9688276166454535
# COMET INFO:     bird_recall                    : 1.0
# COMET INFO:     bird_support                   : 16
# COMET INFO:     bird_true_positives            : 16.0
# COMET INFO:     boat_f1                        : 0.561000436527241
# COMET INFO:     boat_false_positives           : 0.0
# COMET INFO:     boat_mAP@.5                    : 0.5819548214942951
# COMET INFO:     boat_mAP@.5:.95                : 0.3112332951101416
# COMET INFO:     boat_precision                 : 1.0
# COMET INFO:     boat_recall                    : 0.3898544869418656
# COMET INFO:     boat_support                   : 6
# COMET INFO:     boat_true_positives            : 2.0
# COMET INFO:     book_f1                        : 0.37736833808282294
# COMET INFO:     book_false_positives           : 5.0
# COMET INFO:     book_mAP@.5                    : 0.3717917878877099
# COMET INFO:     book_mAP@.5:.95                : 0.1830991085401855
# COMET INFO:     book_precision                 : 0.5970642249712017
# COMET INFO:     book_recall                    : 0.27586206896551724
# COMET INFO:     book_support                   : 29
# COMET INFO:     book_true_positives            : 8.0
# COMET INFO:     bottle_f1                      : 0.449235970322881
# COMET INFO:     bottle_false_positives         : 5.0
# COMET INFO:     bottle_mAP@.5                  : 0.532364788176783
# COMET INFO:     bottle_mAP@.5:.95              : 0.2543869753700446
# COMET INFO:     bottle_precision               : 0.5707222680906892
# COMET INFO:     bottle_recall                  : 0.37039265986634407
# COMET INFO:     bottle_support                 : 18
# COMET INFO:     bottle_true_positives          : 7.0
# COMET INFO:     bowl_f1                        : 0.7495776182039597
# COMET INFO:     bowl_false_positives           : 2.0
# COMET INFO:     bowl_mAP@.5                    : 0.7713223255135965
# COMET INFO:     bowl_mAP@.5:.95                : 0.5584233840042219
# COMET INFO:     bowl_precision                 : 0.8987844987844988
# COMET INFO:     bowl_recall                    : 0.6428571428571429
# COMET INFO:     bowl_support                   : 28
# COMET INFO:     bowl_true_positives            : 18.0
# COMET INFO:     broccoli_f1                    : 0.40046340548333575
# COMET INFO:     broccoli_false_positives       : 13.0
# COMET INFO:     broccoli_mAP@.5                : 0.5164567335073564
# COMET INFO:     broccoli_mAP@.5:.95            : 0.3621313004800498
# COMET INFO:     broccoli_precision             : 0.3240703939233351
# COMET INFO:     broccoli_recall                : 0.5239813677313677
# COMET INFO:     broccoli_support               : 11
# COMET INFO:     broccoli_true_positives        : 6.0
# COMET INFO:     bus_f1                         : 0.6642065514081376
# COMET INFO:     bus_false_positives            : 3.0
# COMET INFO:     bus_mAP@.5                     : 0.7214009009009009
# COMET INFO:     bus_mAP@.5:.95                 : 0.63538
# COMET INFO:     bus_precision                  : 0.6206894968362858
# COMET INFO:     bus_recall                     : 0.7142857142857143
# COMET INFO:     bus_support                    : 7
# COMET INFO:     bus_true_positives             : 5.0
# COMET INFO:     cake_f1                        : 0.9215154771010561
# COMET INFO:     cake_false_positives           : 1.0
# COMET INFO:     cake_mAP@.5                    : 0.995
# COMET INFO:     cake_mAP@.5:.95                : 0.7719579439252336
# COMET INFO:     cake_precision                 : 0.8544540580184145
# COMET INFO:     cake_recall                    : 1.0
# COMET INFO:     cake_support                   : 4
# COMET INFO:     cake_true_positives            : 4.0
# COMET INFO:     car_f1                         : 0.555692778999045
# COMET INFO:     car_false_positives            : 11.0
# COMET INFO:     car_mAP@.5                     : 0.5610565305478551
# COMET INFO:     car_mAP@.5:.95                 : 0.23928364421577944
# COMET INFO:     car_precision                  : 0.6630411924529571
# COMET INFO:     car_recall                     : 0.4782608695652174
# COMET INFO:     car_support                    : 46
# COMET INFO:     car_true_positives             : 22.0
# COMET INFO:     carrot_f1                      : 0.715647724457311
# COMET INFO:     carrot_false_positives         : 8.0
# COMET INFO:     carrot_mAP@.5                  : 0.7457772995617865
# COMET INFO:     carrot_mAP@.5:.95              : 0.4951000596047879
# COMET INFO:     carrot_precision               : 0.6902394388108674
# COMET INFO:     carrot_recall                  : 0.7429981001409572
# COMET INFO:     carrot_support                 : 24
# COMET INFO:     carrot_true_positives          : 18.0
# COMET INFO:     cat_f1                         : 0.9212212773782947
# COMET INFO:     cat_false_positives            : 1.0
# COMET INFO:     cat_mAP@.5                     : 0.995
# COMET INFO:     cat_mAP@.5:.95                 : 0.7967772277227723
# COMET INFO:     cat_precision                  : 0.8539483195770621
# COMET INFO:     cat_recall                     : 1.0
# COMET INFO:     cat_support                    : 4
# COMET INFO:     cat_true_positives             : 4.0
# COMET INFO:     cell phone_f1                  : 0.47695255151445737
# COMET INFO:     cell phone_false_positives     : 2.0
# COMET INFO:     cell phone_mAP@.5              : 0.490634588917059
# COMET INFO:     cell phone_mAP@.5:.95          : 0.29593245469951074
# COMET INFO:     cell phone_precision           : 0.6550407550407551
# COMET INFO:     cell phone_recall              : 0.375
# COMET INFO:     cell phone_support             : 8
# COMET INFO:     cell phone_true_positives      : 3.0
# COMET INFO:     chair_f1                       : 0.5845168184720784
# COMET INFO:     chair_false_positives          : 18.0
# COMET INFO:     chair_mAP@.5                   : 0.6372743472761944
# COMET INFO:     chair_mAP@.5:.95               : 0.3563094525387802
# COMET INFO:     chair_precision                : 0.5462330485110053
# COMET INFO:     chair_recall                   : 0.6285714285714286
# COMET INFO:     chair_support                  : 35
# COMET INFO:     chair_true_positives           : 22.0
# COMET INFO:     clock_f1                       : 0.8823404281409906
# COMET INFO:     clock_false_positives          : 1.0
# COMET INFO:     clock_mAP@.5                   : 0.951
# COMET INFO:     clock_mAP@.5:.95               : 0.702344905565941
# COMET INFO:     clock_precision                : 0.8758877470435259
# COMET INFO:     clock_recall                   : 0.8888888888888888
# COMET INFO:     clock_support                  : 9
# COMET INFO:     clock_true_positives           : 8.0
# COMET INFO:     couch_f1                       : 0.7589542194727233
# COMET INFO:     couch_false_positives          : 1.0
# COMET INFO:     couch_mAP@.5                   : 0.8602747252747251
# COMET INFO:     couch_mAP@.5:.95               : 0.5466936143929602
# COMET INFO:     couch_precision                : 0.8808981166597061
# COMET INFO:     couch_recall                   : 0.6666666666666666
# COMET INFO:     couch_support                  : 6
# COMET INFO:     couch_true_positives           : 4.0
# COMET INFO:     cup_f1                         : 0.7039285790786312
# COMET INFO:     cup_false_positives            : 5.0
# COMET INFO:     cup_mAP@.5                     : 0.8372871869517008
# COMET INFO:     cup_mAP@.5:.95                 : 0.5295062469955637
# COMET INFO:     cup_precision                  : 0.8165938046890427
# COMET INFO:     cup_recall                     : 0.6185828685828686
# COMET INFO:     cup_support                    : 36
# COMET INFO:     cup_true_positives             : 22.0
# COMET INFO:     dining table_f1                : 0.5060530151372483
# COMET INFO:     dining table_false_positives   : 1.0
# COMET INFO:     dining table_mAP@.5            : 0.5814542801029895
# COMET INFO:     dining table_mAP@.5:.95        : 0.3343553907521737
# COMET INFO:     dining table_precision         : 0.8248299846237991
# COMET INFO:     dining table_recall            : 0.36499227220876707
# COMET INFO:     dining table_support           : 13
# COMET INFO:     dining table_true_positives    : 5.0
# COMET INFO:     dog_f1                         : 0.7942838655889832
# COMET INFO:     dog_false_positives            : 0.0
# COMET INFO:     dog_mAP@.5                     : 0.9119642857142858
# COMET INFO:     dog_mAP@.5:.95                 : 0.6805553360510458
# COMET INFO:     dog_precision                  : 0.9823265001542566
# COMET INFO:     dog_recall                     : 0.6666666666666666
# COMET INFO:     dog_support                    : 9
# COMET INFO:     dog_true_positives             : 6.0
# COMET INFO:     donut_f1                       : 0.7532403708241475
# COMET INFO:     donut_false_positives          : 9.0
# COMET INFO:     donut_mAP@.5                   : 0.9504861111111111
# COMET INFO:     donut_mAP@.5:.95               : 0.8240360833333332
# COMET INFO:     donut_precision                : 0.6041584546028838
# COMET INFO:     donut_recall                   : 1.0
# COMET INFO:     donut_support                  : 14
# COMET INFO:     donut_true_positives           : 14.0
# COMET INFO:     elephant_f1                    : 0.9559151369815234
# COMET INFO:     elephant_false_positives       : 0.0
# COMET INFO:     elephant_mAP@.5                : 0.9460652741514362
# COMET INFO:     elephant_mAP@.5:.95            : 0.7178943574807637
# COMET INFO:     elephant_precision             : 1.0
# COMET INFO:     elephant_recall                : 0.9155531038137529
# COMET INFO:     elephant_support               : 17
# COMET INFO:     elephant_true_positives        : 16.0
# COMET INFO:     fork_f1                        : 0.489266287112829
# COMET INFO:     fork_false_positives           : 0.0
# COMET INFO:     fork_mAP@.5                    : 0.5206231884057971
# COMET INFO:     fork_mAP@.5:.95                : 0.32172840717836204
# COMET INFO:     fork_precision                 : 1.0
# COMET INFO:     fork_recall                    : 0.3238600442547811
# COMET INFO:     fork_support                   : 6
# COMET INFO:     fork_true_positives            : 2.0
# COMET INFO:     frisbee_f1                     : 0.7576412134935326
# COMET INFO:     frisbee_false_positives        : 2.0
# COMET INFO:     frisbee_mAP@.5                 : 0.7995161290322581
# COMET INFO:     frisbee_mAP@.5:.95             : 0.7265
# COMET INFO:     frisbee_precision              : 0.7195425280818539
# COMET INFO:     frisbee_recall                 : 0.8
# COMET INFO:     frisbee_support                : 5
# COMET INFO:     frisbee_true_positives         : 4.0
# COMET INFO:     giraffe_f1                     : 0.8648721630555474
# COMET INFO:     giraffe_false_positives        : 1.0
# COMET INFO:     giraffe_mAP@.5                 : 0.9308333333333333
# COMET INFO:     giraffe_mAP@.5:.95             : 0.7819221153846155
# COMET INFO:     giraffe_precision              : 0.8421191015275884
# COMET INFO:     giraffe_recall                 : 0.8888888888888888
# COMET INFO:     giraffe_support                : 9
# COMET INFO:     giraffe_true_positives         : 8.0
# COMET INFO:     handbag_f1                     : 0.3679103131940601
# COMET INFO:     handbag_false_positives        : 3.0
# COMET INFO:     handbag_mAP@.5                 : 0.35127103514326874
# COMET INFO:     handbag_mAP@.5:.95             : 0.19081804946634054
# COMET INFO:     handbag_precision              : 0.6112067950303245
# COMET INFO:     handbag_recall                 : 0.2631578947368421
# COMET INFO:     handbag_support                : 19
# COMET INFO:     handbag_true_positives         : 5.0
# COMET INFO:     horse_f1                       : 0.8980318446406855
# COMET INFO:     horse_false_positives          : 0.0
# COMET INFO:     horse_mAP@.5                   : 0.995
# COMET INFO:     horse_mAP@.5:.95               : 0.6221423076923077
# COMET INFO:     horse_precision                : 0.8149344790711015
# COMET INFO:     horse_recall                   : 1.0
# COMET INFO:     horse_support                  : 2
# COMET INFO:     horse_true_positives           : 2.0
# COMET INFO:     hot dog_f1                     : 0.6885500237192359
# COMET INFO:     hot dog_false_positives        : 2.0
# COMET INFO:     hot dog_mAP@.5                 : 0.995
# COMET INFO:     hot dog_mAP@.5:.95             : 0.8955
# COMET INFO:     hot dog_precision              : 0.525029575029575
# COMET INFO:     hot dog_recall                 : 1.0
# COMET INFO:     hot dog_support                : 2
# COMET INFO:     hot dog_true_positives         : 2.0
# COMET INFO:     kite_f1                        : 0.6028186944338741
# COMET INFO:     kite_false_positives           : 4.0
# COMET INFO:     kite_mAP@.5                    : 0.5986765685295097
# COMET INFO:     kite_mAP@.5:.95                : 0.2528727779337683
# COMET INFO:     kite_precision                 : 0.605663997330664
# COMET INFO:     kite_recall                    : 0.6
# COMET INFO:     kite_support                   : 10
# COMET INFO:     kite_true_positives            : 6.0
# COMET INFO:     knife_f1                       : 0.7647083980077286
# COMET INFO:     knife_false_positives          : 3.0
# COMET INFO:     knife_mAP@.5                   : 0.750391238987278
# COMET INFO:     knife_mAP@.5:.95               : 0.4250877813929204
# COMET INFO:     knife_precision                : 0.7800052345923906
# COMET INFO:     knife_recall                   : 0.75
# COMET INFO:     knife_support                  : 16
# COMET INFO:     knife_true_positives           : 12.0
# COMET INFO:     laptop_f1                      : 0.0
# COMET INFO:     laptop_false_positives         : 0.0
# COMET INFO:     laptop_mAP@.5                  : 0.8300000000000002
# COMET INFO:     laptop_mAP@.5:.95              : 0.4993149390243904
# COMET INFO:     laptop_precision               : 1.0
# COMET INFO:     laptop_recall                  : 0.0
# COMET INFO:     laptop_support                 : 3
# COMET INFO:     laptop_true_positives          : 0.0
# COMET INFO:     loss [4]                       : (1.9564577341079712, 2.2340574264526367)
# COMET INFO:     metrics/mAP_0.5 [10]           : (0.6860396060267557, 0.7615284201521582)
# COMET INFO:     metrics/mAP_0.5:0.95 [10]      : (0.45314582191797603, 0.5092766298013401)
# COMET INFO:     metrics/precision [10]         : (0.687996176511977, 0.7831448740091492)
# COMET INFO:     metrics/recall [10]            : (0.602999074233154, 0.667936975820754)
# COMET INFO:     microwave_f1                   : 0.8853110909618697
# COMET INFO:     microwave_false_positives      : 1.0
# COMET INFO:     microwave_mAP@.5               : 0.995
# COMET INFO:     microwave_mAP@.5:.95           : 0.7436379787234042
# COMET INFO:     microwave_precision            : 0.7942225707850707
# COMET INFO:     microwave_recall               : 1.0
# COMET INFO:     microwave_support              : 3
# COMET INFO:     microwave_true_positives       : 3.0
# COMET INFO:     motorcycle_f1                  : 0.8757253955575776
# COMET INFO:     motorcycle_false_positives     : 1.0
# COMET INFO:     motorcycle_mAP@.5              : 0.9616666666666666
# COMET INFO:     motorcycle_mAP@.5:.95          : 0.7408719512195121
# COMET INFO:     motorcycle_precision           : 0.778924821478013
# COMET INFO:     motorcycle_recall              : 1.0
# COMET INFO:     motorcycle_support             : 5
# COMET INFO:     motorcycle_true_positives      : 5.0
# COMET INFO:     mouse_f1                       : 0.0
# COMET INFO:     mouse_false_positives          : 0.0
# COMET INFO:     mouse_mAP@.5                   : 0.0
# COMET INFO:     mouse_mAP@.5:.95               : 0.0
# COMET INFO:     mouse_precision                : 1.0
# COMET INFO:     mouse_recall                   : 0.0
# COMET INFO:     mouse_support                  : 2
# COMET INFO:     mouse_true_positives           : 0.0
# COMET INFO:     orange_f1                      : 0.8804106718930024
# COMET INFO:     orange_false_positives         : 1.0
# COMET INFO:     orange_mAP@.5                  : 0.995
# COMET INFO:     orange_mAP@.5:.95              : 0.6596305031446541
# COMET INFO:     orange_precision               : 0.7863692961253937
# COMET INFO:     orange_recall                  : 1.0
# COMET INFO:     orange_support                 : 4
# COMET INFO:     orange_true_positives          : 4.0
# COMET INFO:     oven_f1                        : 0.39230993883921655
# COMET INFO:     oven_false_positives           : 3.0
# COMET INFO:     oven_mAP@.5                    : 0.4744890510948905
# COMET INFO:     oven_mAP@.5:.95                : 0.31997992700729927
# ...
# COMET INFO:     sink_f1                        : 0.38067200344134583
# COMET INFO:     sink_false_positives           : 3.0
# COMET INFO:     sink_mAP@.5                    : 0.40008038538970375
# COMET INFO:     sink_mAP@.5:.95                : 0.3098979301121657
# COMET INFO:     sink_precision                 : 0.4436819428123776
# COMET INFO:     sink_recall                    : 0.3333333333333333
# COMET INFO:     sink_support                   : 6
# COMET INFO:     sink_true_positives            : 2.0
# COMET INFO:     skateboard_f1                  : 0.6623332158083889
# COMET INFO:     skateboard_false_positives     : 1.0
# COMET INFO:     skateboard_mAP@.5              : 0.6802777777777778
# COMET INFO:     skateboard_mAP@.5:.95          : 0.49051450506261657
# COMET INFO:     skateboard_precision           : 0.7391193601117265
# COMET INFO:     skateboard_recall              : 0.6
# COMET INFO:     skateboard_support             : 5
# COMET INFO:     skateboard_true_positives      : 3.0
# COMET INFO:     skis_f1                        : 0.9041686202409612
# COMET INFO:     skis_false_positives           : 0.0
# COMET INFO:     skis_mAP@.5                    : 0.995
# COMET INFO:     skis_mAP@.5:.95                : 0.31659090909090903
# COMET INFO:     skis_precision                 : 0.8250983106906266
# COMET INFO:     skis_recall                    : 1.0
# COMET INFO:     skis_support                   : 1
# COMET INFO:     skis_true_positives            : 1.0
# COMET INFO:     snowboard_f1                   : 0.8323006143287126
# COMET INFO:     snowboard_false_positives      : 0.0
# COMET INFO:     snowboard_mAP@.5               : 0.8899999999999999
# COMET INFO:     snowboard_mAP@.5:.95           : 0.5330715941446054
# COMET INFO:     snowboard_precision            : 1.0
# COMET INFO:     snowboard_recall               : 0.7127695916789742
# COMET INFO:     snowboard_support              : 7
# COMET INFO:     snowboard_true_positives       : 5.0
# COMET INFO:     spoon_f1                       : 0.5978566154398217
# COMET INFO:     spoon_false_positives          : 4.0
# COMET INFO:     spoon_mAP@.5                   : 0.6443688302306835
# COMET INFO:     spoon_mAP@.5:.95               : 0.3837046846609844
# COMET INFO:     spoon_precision                : 0.7433376233376233
# COMET INFO:     spoon_recall                   : 0.5
# COMET INFO:     spoon_support                  : 22
# COMET INFO:     spoon_true_positives           : 11.0
# COMET INFO:     sports ball_f1                 : 0.6678420766493932
# COMET INFO:     sports ball_false_positives    : 2.0
# COMET INFO:     sports ball_mAP@.5             : 0.621247947454844
# COMET INFO:     sports ball_mAP@.5:.95         : 0.3110940558292282
# COMET INFO:     sports ball_precision          : 0.6690216387186083
# COMET INFO:     sports ball_recall             : 0.6666666666666666
# COMET INFO:     sports ball_support            : 6
# COMET INFO:     sports ball_true_positives     : 4.0
# COMET INFO:     stop sign_f1                   : 0.8597249738861316
# COMET INFO:     stop sign_false_positives      : 1.0
# COMET INFO:     stop sign_mAP@.5               : 0.995
# COMET INFO:     stop sign_mAP@.5:.95           : 0.7469622641509435
# COMET INFO:     stop sign_precision            : 0.7539628196682779
# COMET INFO:     stop sign_recall               : 1.0
# COMET INFO:     stop sign_support              : 2
# COMET INFO:     stop sign_true_positives       : 2.0
# COMET INFO:     suitcase_f1                    : 0.9294609327252237
# COMET INFO:     suitcase_false_positives       : 1.0
# COMET INFO:     suitcase_mAP@.5                : 0.995
# COMET INFO:     suitcase_mAP@.5:.95            : 0.6106890204191089
# COMET INFO:     suitcase_precision             : 0.8682176682176682
# COMET INFO:     suitcase_recall                : 1.0
# COMET INFO:     suitcase_support               : 4
# COMET INFO:     suitcase_true_positives        : 4.0
# COMET INFO:     teddy bear_f1                  : 0.7253656117095492
# COMET INFO:     teddy bear_false_positives     : 6.0
# COMET INFO:     teddy bear_mAP@.5              : 0.7959320949370071
# COMET INFO:     teddy bear_mAP@.5:.95          : 0.5193305213113837
# COMET INFO:     teddy bear_precision           : 0.719058163502608
# COMET INFO:     teddy bear_recall              : 0.7317846947476577
# COMET INFO:     teddy bear_support             : 21
# COMET INFO:     teddy bear_true_positives      : 15.0
# COMET INFO:     tennis racket_f1               : 0.4651659043131951
# COMET INFO:     tennis racket_false_positives  : 3.0
# COMET INFO:     tennis racket_mAP@.5           : 0.5483555496548063
# COMET INFO:     tennis racket_mAP@.5:.95       : 0.29228866966213574
# COMET INFO:     tennis racket_precision        : 0.5085932085932086
# COMET INFO:     tennis racket_recall           : 0.42857142857142855
# COMET INFO:     tennis racket_support          : 7
# COMET INFO:     tennis racket_true_positives   : 3.0
# COMET INFO:     tie_f1                         : 0.7160073748857563
# COMET INFO:     tie_false_positives            : 2.0
# COMET INFO:     tie_mAP@.5                     : 0.7867639999999999
# COMET INFO:     tie_mAP@.5:.95                 : 0.47831377867924524
# COMET INFO:     tie_precision                  : 0.7177373550612988
# COMET INFO:     tie_recall                     : 0.7142857142857143
# COMET INFO:     tie_support                    : 7
# COMET INFO:     tie_true_positives             : 5.0
# COMET INFO:     toilet_f1                      : 0.8778834953960065
# COMET INFO:     toilet_false_positives         : 1.0
# COMET INFO:     toilet_mAP@.5                  : 0.995
# COMET INFO:     toilet_mAP@.5:.95              : 0.8955
# COMET INFO:     toilet_precision               : 0.7823461216318359
# COMET INFO:     toilet_recall                  : 1.0
# COMET INFO:     toilet_support                 : 2
# COMET INFO:     toilet_true_positives          : 2.0
# COMET INFO:     toothbrush_f1                  : 0.8865142200008846
# COMET INFO:     toothbrush_false_positives     : 1.0
# COMET INFO:     toothbrush_mAP@.5              : 0.995
# COMET INFO:     toothbrush_mAP@.5:.95          : 0.7063622754491018
# COMET INFO:     toothbrush_precision           : 0.796161240605685
# COMET INFO:     toothbrush_recall              : 1.0
# COMET INFO:     toothbrush_support             : 5
# COMET INFO:     toothbrush_true_positives      : 5.0
# COMET INFO:     traffic light_f1               : 0.45307983550919206
# COMET INFO:     traffic light_false_positives  : 2.0
# COMET INFO:     traffic light_mAP@.5           : 0.374213142908795
# COMET INFO:     traffic light_mAP@.5:.95       : 0.24831677877299616
# COMET INFO:     traffic light_precision        : 0.6995488256589499
# COMET INFO:     traffic light_recall           : 0.3350375242027107
# COMET INFO:     traffic light_support          : 14
# COMET INFO:     traffic light_true_positives   : 5.0
# COMET INFO:     train/box_loss [10]            : (0.04249417409300804, 0.045501384884119034)
# COMET INFO:     train/cls_loss [10]            : (0.014602642506361008, 0.016743825748562813)
# COMET INFO:     train/obj_loss [10]            : (0.06093379110097885, 0.07007072865962982)
# COMET INFO:     train_f1                       : 0.8458802283796355
# COMET INFO:     train_false_positives          : 0.0
# COMET INFO:     train_mAP@.5                   : 0.995
# COMET INFO:     train_mAP@.5:.95               : 0.4719612931034483
# COMET INFO:     train_precision                : 1.0
# COMET INFO:     train_recall                   : 0.7329223960802908
# COMET INFO:     train_support                  : 3
# COMET INFO:     train_true_positives           : 2.0
# COMET INFO:     truck_f1                       : 0.4580841772128381
# COMET INFO:     truck_false_positives          : 1.0
# COMET INFO:     truck_mAP@.5                   : 0.5228711535133329
# COMET INFO:     truck_mAP@.5:.95               : 0.28097545896181975
# COMET INFO:     truck_precision                : 0.7320591778218897
# COMET INFO:     truck_recall                   : 0.3333333333333333
# COMET INFO:     truck_support                  : 12
# COMET INFO:     truck_true_positives           : 4.0
# COMET INFO:     tv_f1                          : 0.8337898845310262
# COMET INFO:     tv_false_positives             : 1.0
# COMET INFO:     tv_mAP@.5                      : 0.995
# COMET INFO:     tv_mAP@.5:.95                  : 0.796
# COMET INFO:     tv_precision                   : 0.7149568276517051
# COMET INFO:     tv_recall                      : 1.0
# COMET INFO:     tv_support                     : 2
# COMET INFO:     tv_true_positives              : 2.0
# COMET INFO:     umbrella_f1                    : 0.8397937890607218
# COMET INFO:     umbrella_false_positives       : 4.0
# COMET INFO:     umbrella_mAP@.5                : 0.8813160083160083
# COMET INFO:     umbrella_mAP@.5:.95            : 0.5075168714361509
# COMET INFO:     umbrella_precision             : 0.7992100474859096
# COMET INFO:     umbrella_recall                : 0.8847196950645226
# COMET INFO:     umbrella_support               : 18
# COMET INFO:     umbrella_true_positives        : 16.0
# COMET INFO:     val/box_loss [10]              : (0.03937961161136627, 0.041477397084236145)
# COMET INFO:     val/cls_loss [10]              : (0.0077555179595947266, 0.010736465454101562)
# COMET INFO:     val/obj_loss [10]              : (0.035877227783203125, 0.038483619689941406)
# COMET INFO:     vase_f1                        : 0.6769020882320815
# COMET INFO:     vase_false_positives           : 2.0
# COMET INFO:     vase_mAP@.5                    : 0.995
# COMET INFO:     vase_mAP@.5:.95                : 0.8955
# COMET INFO:     vase_precision                 : 0.5116039275790313
# COMET INFO:     vase_recall                    : 1.0
# COMET INFO:     vase_support                   : 2
# COMET INFO:     vase_true_positives            : 2.0
# COMET INFO:     wine glass_f1                  : 0.7830123275119782
# COMET INFO:     wine glass_false_positives     : 6.0
# COMET INFO:     wine glass_mAP@.5              : 0.8999082125603867
# COMET INFO:     wine glass_mAP@.5:.95          : 0.48660911201849755
# COMET INFO:     wine glass_precision           : 0.7085258748026779
# COMET INFO:     wine glass_recall              : 0.875
# COMET INFO:     wine glass_support             : 16
# COMET INFO:     wine glass_true_positives      : 14.0
# COMET INFO:     x/lr0 [10]                     : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                     : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                     : (0.0007, 0.0013892000000000002)
# COMET INFO:     zebra_f1                       : 0.9263462060681947
# COMET INFO:     zebra_false_positives          : 1.0
# COMET INFO:     zebra_mAP@.5                   : 0.995
# COMET INFO:     zebra_mAP@.5:.95               : 0.8862500000000001
# COMET INFO:     zebra_precision                : 0.8627978695775307
# COMET INFO:     zebra_recall                   : 1.0
# COMET INFO:     zebra_support                  : 4
# COMET INFO:     zebra_true_positives           : 4.0
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : victoria-celia-cesar-ferreira/comet-example-yolov5/265245b0bb16487a96854e38fa69e9d6
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : True
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp5
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.84 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# ## Uploading a Dataset to Comet Artifacts
#
#
# If you would like to store your data using [Comet Artifacts](https://www.comet.com/docs/v2/guides/data-management/using-artifacts/#learn-more?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab), you can do so using the `upload_dataset` flag.
#
# The dataset be organized in the way described in the [YOLOv5 documentation](https://docs.ultralytics.com/tutorials/train-custom-datasets/#3-organize-directories). The dataset config `yaml` file must follow the same format as that of the `coco128.yaml` file.

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1 \
--upload_dataset "train"
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=train, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-484-g70b964b6 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/511dd4b7d1ec463dbb80ebcbb4fc3762
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:900: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp6/labels.jpg...
# COMET ERROR: Error adding file to Artifact. Skipping file.
# COMET ERROR: Invalid file_data '/content/datasets/coco128/labels/train2017/000000000250.txt', must either be a valid file-path or an IO object
# COMET ERROR: Error adding file to Artifact. Skipping file.
# COMET ERROR: Invalid file_data '/content/datasets/coco128/labels/train2017/000000000508.txt', must either be a valid file-path or an IO object
# COMET INFO: Artifact 'yolov5-dataset' version 1.0.0 created
# COMET INFO: Scheduling the upload of 254 assets: 254 local assets for a size of 6.64 MB, and 0 remote assets (will be linked, not uploaded). This can take some time.
# COMET INFO: Artifact 'victoria-celia-cesar-ferreira/yolov5-dataset:1.0.0' has started uploading asynchronously
# /content/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp6
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.52G    0.04429    0.06439    0.01392        197        640:  12% 1/8 [00:03<00:23,  3.41s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04407    0.05901    0.01749        154        640:  25% 2/8 [00:03<00:09,  1.63s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04462     0.0584    0.01643        180        640:  38% 3/8 [00:04<00:05,  1.05s/it]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04398    0.05708     0.0173        158        640:  50% 4/8 [00:04<00:03,  1.18it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04501     0.0593    0.01752        198        640:  62% 5/8 [00:05<00:02,  1.49it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04487    0.05856    0.01718        163        640:  75% 6/8 [00:05<00:01,  1.84it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G    0.04522    0.06052    0.01704        221        640:  88% 7/8 [00:05<00:00,  2.16it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.56G     0.0455    0.06219    0.01654        237        640: 100% 8/8 [00:05<00:00,  1.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:10<00:00,  2.67s/it]
#                    all        128        929      0.688      0.603      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04029    0.08238    0.01446        250        640:  12% 1/8 [00:00<00:02,  3.33it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04202    0.07559    0.01437        231        640:  25% 2/8 [00:00<00:01,  3.41it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04274    0.07337     0.0164        209        640:  38% 3/8 [00:00<00:01,  3.37it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G     0.0434    0.07157    0.01732        230        640:  50% 4/8 [00:01<00:01,  3.26it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04254    0.07056    0.01644        217        640:  62% 5/8 [00:01<00:00,  3.30it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04275    0.06484    0.01753        103        640:  75% 6/8 [00:01<00:00,  3.23it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      5.18G    0.04342    0.06405    0.01704        200        640:  88% 7/8 [00:02<00:00,  3.26it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# COMET INFO: Artifact 'victoria-celia-cesar-ferreira/yolov5-dataset:1.0.0' has been fully uploaded successfully
#         1/4      5.18G    0.04359    0.06471    0.01674        245        640: 100% 8/8 [00:02<00:00,  3.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.07s/it]
#                    all        128        929       0.74      0.606      0.712       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G      0.043    0.05793    0.01393        180        640:  12% 1/8 [00:00<00:01,  3.88it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04637    0.07675    0.01568        308        640:  25% 2/8 [00:00<00:01,  4.13it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04684    0.07683    0.01638        293        640:  38% 3/8 [00:00<00:01,  3.40it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04627    0.07429     0.0152        190        640:  50% 4/8 [00:01<00:01,  3.45it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04612    0.07508    0.01533        272        640:  62% 5/8 [00:01<00:00,  3.24it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04608    0.07408    0.01506        232        640:  75% 6/8 [00:01<00:00,  3.35it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04561     0.0711    0.01551        169        640:  88% 7/8 [00:02<00:00,  3.06it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      5.18G    0.04543    0.07007    0.01516        217        640: 100% 8/8 [00:02<00:00,  3.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.03it/s]
#                    all        128        929      0.749      0.619      0.725      0.485
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G     0.0437    0.05881    0.01532        209        640:  12% 1/8 [00:00<00:01,  3.94it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04584    0.06511    0.01573        273        640:  25% 2/8 [00:00<00:01,  4.21it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04513    0.06103    0.01626        164        640:  38% 3/8 [00:00<00:01,  3.55it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04538    0.06103    0.01609        214        640:  50% 4/8 [00:01<00:01,  3.66it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04555    0.06131    0.01607        229        640:  62% 5/8 [00:01<00:00,  3.33it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04588    0.06204    0.01587        260        640:  75% 6/8 [00:01<00:00,  3.47it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04578    0.06236    0.01544        214        640:  88% 7/8 [00:02<00:00,  3.28it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      5.18G    0.04498    0.06093    0.01524        194        640: 100% 8/8 [00:02<00:00,  3.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  2.10it/s]
#                    all        128        929      0.783      0.619      0.738      0.501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04838    0.07358    0.01403        284        640:  12% 1/8 [00:00<00:02,  3.10it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04556    0.06641    0.01303        192        640:  25% 2/8 [00:00<00:01,  3.05it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04457     0.0648    0.01525        203        640:  38% 3/8 [00:01<00:01,  2.58it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04301    0.06488    0.01491        199        640:  50% 4/8 [00:01<00:01,  2.67it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04299     0.0633    0.01436        215        640:  62% 5/8 [00:01<00:01,  2.66it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04244    0.06063    0.01436        183        640:  75% 6/8 [00:02<00:00,  2.89it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04288    0.06288    0.01464        284        640:  88% 7/8 [00:02<00:00,  2.78it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      5.18G    0.04249    0.06219     0.0146        168        640: 100% 8/8 [00:02<00:00,  2.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.59it/s]
#                    all        128        929       0.77      0.668      0.762      0.509
#
# 5 epochs completed in 0.011 hours.
# Optimizer stripped from runs/train/exp6/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp6/weights/best.pt, 14.8MB
#
# Validating runs/train/exp6/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.05it/s]
#                    all        128        929      0.769      0.668      0.762       0.51
#                 person        128        254      0.862      0.716      0.807      0.536
#                bicycle        128          6      0.776      0.586      0.623      0.363
#                    car        128         46      0.663      0.478      0.561      0.239
#             motorcycle        128          5      0.779          1      0.962      0.741
#               airplane        128          6      0.992          1      0.995      0.745
#                    bus        128          7      0.621      0.714      0.721      0.635
#                  train        128          3          1      0.733      0.995      0.472
#                  truck        128         12      0.732      0.333      0.523      0.281
#                   boat        128          6          1       0.39      0.582      0.311
#          traffic light        128         14        0.7      0.335      0.374      0.248
#              stop sign        128          2      0.754          1      0.995      0.747
#                  bench        128          9      0.657      0.667      0.739      0.366
#                   bird        128         16      0.969          1      0.995      0.678
#                    cat        128          4      0.854          1      0.995      0.797
#                    dog        128          9      0.982      0.667      0.912      0.681
#                  horse        128          2      0.815          1      0.995      0.622
#               elephant        128         17          1      0.916      0.946      0.718
#                   bear        128          1      0.676          1      0.995      0.895
#                  zebra        128          4      0.863          1      0.995      0.886
#                giraffe        128          9      0.842      0.889      0.931      0.782
#               backpack        128          6      0.863        0.5      0.715      0.374
#               umbrella        128         18      0.799      0.885      0.881      0.508
#                handbag        128         19      0.611      0.263      0.351      0.191
#                    tie        128          7      0.718      0.714      0.787      0.478
#               suitcase        128          4      0.868          1      0.995      0.611
#                frisbee        128          5       0.72        0.8        0.8      0.727
#                   skis        128          1      0.825          1      0.995      0.317
#              snowboard        128          7          1      0.713       0.89      0.533
#            sports ball        128          6      0.669      0.667      0.621      0.311
#                   kite        128         10      0.606        0.6      0.599      0.253
#           baseball bat        128          4      0.841        0.5      0.544      0.233
#         baseball glove        128          7      0.553      0.429      0.464      0.283
#             skateboard        128          5      0.739        0.6       0.68      0.491
#          tennis racket        128          7      0.509      0.429      0.548      0.292
#                 bottle        128         18      0.571       0.37      0.532      0.254
#             wine glass        128         16      0.709      0.875        0.9      0.487
#                    cup        128         36      0.817      0.619      0.837       0.53
#                   fork        128          6          1      0.324      0.521      0.322
#                  knife        128         16       0.78       0.75       0.75      0.425
#                  spoon        128         22      0.743        0.5      0.644      0.384
#                   bowl        128         28      0.899      0.643      0.771      0.558
#                 banana        128          1      0.815          1      0.995      0.307
#               sandwich        128          2          1          0      0.662      0.579
#                 orange        128          4      0.786          1      0.995       0.66
#               broccoli        128         11      0.324      0.524      0.516      0.362
#                 carrot        128         24       0.69      0.743      0.746      0.495
#                hot dog        128          2      0.525          1      0.995      0.895
#                  pizza        128          5       0.87        0.8       0.92      0.729
#                  donut        128         14      0.604          1       0.95      0.824
#                   cake        128          4      0.854          1      0.995      0.772
#                  chair        128         35      0.546      0.629      0.637      0.356
#                  couch        128          6      0.881      0.667       0.86      0.547
#           potted plant        128         14      0.643      0.714      0.784      0.499
#                    bed        128          3          1          0      0.753      0.499
#           dining table        128         13      0.825      0.365      0.581      0.334
#                 toilet        128          2      0.782          1      0.995      0.895
#                     tv        128          2      0.715          1      0.995      0.796
#                 laptop        128          3          1          0       0.83      0.499
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.613      0.629      0.531
#             cell phone        128          8      0.655      0.375      0.491      0.296
#              microwave        128          3      0.794          1      0.995      0.744
#                   oven        128          5      0.385        0.4      0.474       0.32
#                   sink        128          6      0.444      0.333        0.4       0.31
#           refrigerator        128          5      0.572        0.8      0.811      0.547
#                   book        128         29      0.597      0.276      0.372      0.183
#                  clock        128          9      0.876      0.889      0.951      0.702
#                   vase        128          2      0.512          1      0.995      0.895
#               scissors        128          1          1          0      0.497     0.0995
#             teddy bear        128         21      0.719      0.732      0.796      0.519
#             toothbrush        128          5      0.796          1      0.995      0.706
# Results saved to runs/train/exp6
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/victoria-celia-cesar-ferreira/comet-example-yolov5/511dd4b7d1ec463dbb80ebcbb4fc3762
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.9564577341079712, 2.2340574264526367)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6860396060267557, 0.7615284201521582)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.45314582191797603, 0.5092766298013401)
# COMET INFO:     metrics/precision [10]    : (0.687996176511977, 0.7831448740091492)
# COMET INFO:     metrics/recall [10]       : (0.602999074233154, 0.667936975820754)
# COMET INFO:     train/box_loss [10]       : (0.04249417409300804, 0.045501384884119034)
# COMET INFO:     train/cls_loss [10]       : (0.014602642506361008, 0.016743825748562813)
# COMET INFO:     train/obj_loss [10]       : (0.06093379110097885, 0.07007072865962982)
# COMET INFO:     val/box_loss [10]         : (0.03937961161136627, 0.041477397084236145)
# COMET INFO:     val/cls_loss [10]         : (0.0077555179595947266, 0.010736465454101562)
# COMET INFO:     val/obj_loss [10]         : (0.035877227783203125, 0.038483619689941406)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : victoria-celia-cesar-ferreira/comet-example-yolov5/511dd4b7d1ec463dbb80ebcbb4fc3762
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp6
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     artifact assets     : 254 (6.64 MB)
# COMET INFO:     artifacts           : 1
# COMET INFO:     asset               : 13 (3.84 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# You can find the uploaded dataset in the Artifacts tab in your Comet Workspace
# <img width="1073" alt="artifact-1" src="https://user-images.githubusercontent.com/7529846/186929193-162718bf-ec7b-4eb9-8c3b-86b3763ef8ea.png">
#
# You can preview the data directly in the Comet UI.
# <img width="1082" alt="artifact-2" src="https://user-images.githubusercontent.com/7529846/186929215-432c36a9-c109-4eb0-944b-84c2786590d6.png">
#
# Artifacts are versioned and also support adding metadata about the dataset. Comet will automatically log the metadata from your dataset `yaml` file
# <img width="963" alt="artifact-3" src="https://user-images.githubusercontent.com/7529846/186929256-9d44d6eb-1a19-42de-889a-bcbca3018f2e.png">

# %% [markdown]
# ### Using a saved Artifact
#
#
# If you would like to use a dataset from Comet Artifacts, set the `path` variable in your dataset `yaml` file to point to the following Artifact resource URL.
#
# ```
# # contents of artifact.yaml file
# path:"comet://<workspace name>/<artifact name>:<artifact version or alias>"
# ```
# Then pass this file to your training script

# %%
# !echo "path: \"comet://examples/yolov5-dataset:latest\"" >> /content/yolov5/data/artifact.yaml

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data /content/yolov5/data/artifact.yaml \
--bbox_interval 1 \
--weights yolov5s.pt \
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--imgsz IMGSZ]
#                 [--rect] [--resume [RESUME]] [--nosave] [--noval]
#                 [--noautoanchor] [--noplots] [--evolve [EVOLVE]]
#                 [--evolve_population EVOLVE_POPULATION]
#                 [--resume_evolve RESUME_EVOLVE] [--bucket BUCKET]
#                 [--cache [CACHE]] [--image-weights] [--device DEVICE]
#                 [--multi-scale] [--single-cls] [--optimizer {SGD,Adam,AdamW}]
#                 [--sync-bn] [--workers WORKERS] [--project PROJECT]
#                 [--name NAME] [--exist-ok] [--quad] [--cos-lr]
#                 [--label-smoothing LABEL_SMOOTHING] [--patience PATIENCE]
#                 [--freeze FREEZE [FREEZE ...]] [--save-period SAVE_PERIOD]
#                 [--seed SEED] [--local_rank LOCAL_RANK] [--entity ENTITY]
#                 [--upload_dataset [UPLOAD_DATASET]]
#                 [--bbox_interval BBOX_INTERVAL]
#                 [--artifact_alias ARTIFACT_ALIAS] [--ndjson-console]
#                 [--ndjson-file]
# train.py: error: unrecognized arguments: \

# %% [markdown]
# Artifacts also allow you to track the lineage of data as it flows through your Experimentation workflow. Here you can see a graph that shows you all the experiments that have used your uploaded dataset.
# <img width="1391" alt="artifact-4" src="https://user-images.githubusercontent.com/7529846/186929264-4c4014fa-fe51-4f3c-a5c5-f6d24649b1b4.png">

# %% [markdown]
# ## Resuming a Training Run
#
# If your training run is interrupted for any reason, e.g. disrupted internet connection, you can resume the run using the `resume` flag and the Comet Run Path.
#
# The Run Path has the following format `comet://<your workspace name>/<your project name>/<experiment id>`.
#
# This will restore the run to its state before the interruption, which includes restoring the  model from a checkpoint, restoring all hyperparameters and training arguments and downloading Comet dataset Artifacts if they were used in the original run. The resumed run will continue logging to the existing Experiment in the Comet UI

# %%
# !python train.py \
--resume "comet://<your run path>"
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=comet://<your run path>, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 987, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 641, in main
#     if opt.resume and not check_comet_resume(opt) and not opt.evolve:
#                           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/loggers/comet/comet_utils.py", line 138, in check_comet_resume
#     experiment = api.get(experiment_path)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/api.py", line 4468, in get
#     return self.get_projects(workspace)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/api.py", line 5276, in get_projects
#     return self._client.get_projects(workspace)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/connection/connection_api.py", line 2235, in get_projects
#     results = self.get_from_endpoint("projects", payload)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/connection/connection_api.py", line 4737, in get_from_endpoint
#     retval = super().get_from_endpoint(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/connection/connection_api.py", line 1498, in get_from_endpoint
#     response = self.get(
#                ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/connection/connection_api.py", line 1700, in get
#     return super().get(
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/comet_ml/connection/connection_api.py", line 1482, in get
#     raise CometRestApiException("GET", response)
# comet_ml.exceptions.CometRestApiException: GET https://www.comet.com/api/rest/v2/projects?workspaceName=%3Cyour+run+path%3E failed with status code 400: Non existing workspace
